# %% [markdown]
# # RootIQ - 08: Model & System Evaluation
# Evaluates Precision, Recall, F1, ROC-AUC for Anomaly Detection, and Top-1/Top-3 Accuracy and MRR for Root Cause Ranking.

# %%
import json
with open('../outputs/evaluation_results/root_cause_evaluation.json') as f:
    rc_eval = json.load(f)
print('Root Cause Ranking Evaluation:', json.dumps(rc_eval, indent=2))
