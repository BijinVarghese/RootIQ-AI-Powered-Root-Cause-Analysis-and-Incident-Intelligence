# %% [markdown]
# # RootIQ - 07: Multi-Source Root Cause Analysis
# Combines Anomaly, Temporal, Metric, Log, and Graph evidence into composite root-cause scores and Top-1/Top-3 rankings.

# %%
import sys; sys.path.append('..')
from src.root_cause.evidence_engine import EvidenceEngine
from src.root_cause.root_cause_scorer import RootCauseScorer
from src.root_cause.root_cause_ranker import RootCauseRanker

ev_engine = EvidenceEngine()
scorer = RootCauseScorer()
ranker = RootCauseRanker(scorer)

# Inspect ranked causes for an incident
print('Root Cause Engine initialized successfully.')
