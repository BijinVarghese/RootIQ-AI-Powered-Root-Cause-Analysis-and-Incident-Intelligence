# %% [markdown]
# # RootIQ - 02: Telemetry Preprocessing
# Normalizes timestamps, cleans severity levels, handles missing telemetry, and resamples to uniform time windows.

# %%
import sys; sys.path.append('..')
import pandas as pd
from src.preprocessing.log_preprocessor import LogPreprocessor
from src.preprocessing.metric_preprocessor import MetricPreprocessor
from src.preprocessing.trace_preprocessor import TracePreprocessor

raw_metrics = pd.read_csv('../data/raw/metrics/telemetry_metrics.csv')
mp = MetricPreprocessor()
cleaned_metrics = mp.clean(raw_metrics)
print('Cleaned metrics rows:', len(cleaned_metrics))
cleaned_metrics.head()
