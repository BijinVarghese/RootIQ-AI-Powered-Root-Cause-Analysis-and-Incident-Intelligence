# %% [markdown]
# # RootIQ - 05: Time-Series Analysis & Anomaly Onset
# Determines the earliest onset timestamp for each anomalous service to establish temporal precedence.

# %%
import sys; sys.path.append('..')
from src.time_series.anomaly_timeline import AnomalyTimeline

timeline = AnomalyTimeline()
onsets = timeline.extract_onset_times(preds)
print('Ordered Anomaly Onset Sequence:')
onsets
